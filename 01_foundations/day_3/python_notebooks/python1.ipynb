# %% [markdown]
# # Python Basics

# %% [markdown]
# **What is Python?**
#
# Python is a versatile, high-level programming language that is easy to learn and use. It is widely used in various domains such as web development, data science, machine learning, and more....
#
# **Why Use Python?**
# - Simple and readable syntax.
# - Huge standard library.
# - Cross-platform compatibility.

# %% [markdown]
# ## Section 1: Variables

# %% [markdown]
# ### Variables
# In Python, variables are used to store data values, and the type of each variable is automatically determined based on the value assigned to it. Variables can be counted or measured. We can treat variables like a container!
# - **Example: Variables & its Types**
#
# ```python
# # int(counted): Integer type, stores whole numbers.
# int: 10
#
# # float(measured): Floating-point type, stores numbers with decimal points.
# float: 3.14
#
# # complex: Complex number type, stores numbers with both real and imaginary parts.
# complex: (1+2j)
#
# # str: String type, stores sequences of characters (text).
# str: Hello, World!
#
# # list: List type, an ordered and mutable collection of elements.
# list: [1, 2, 3, 'apple']
#
# # tuple: Tuple type, an ordered but immutable collection of elements.
# tuple: (1, 2, 3, 'banana')
#
# # dict: Dictionary type, stores key-value pairs.
# dict: {'key1': 'value1', 'key2': 42}
#
# # set: Set type, stores unordered collections of unique elements.
# set: {1, 2, 3, 4}
#
# # frozenset: Frozenset type, an immutable version of a set.
# frozenset: frozenset({1, 2, 3, 4})
#
# # bool: Boolean type, stores either True or False.
# bool: True
#
# # bytes: Bytes type, stores immutable sequences of bytes.
# bytes: b'Hello'
#
# # NoneType: Represents the absence of a value or a null value.
# NoneType: None
#
# ```

# %% [markdown]
# ### Task 1 : Numeric & floats
#     - Create 2 variable a & b , then assign them numeric values eqaul to 77 and 3

# %%
a = 77
b = 3

# %% [markdown]
#     - print them , Then make 4 new variables :
#         - sum_ab           # sum        => +
#         - diff_ab          # Difference => -
#         - prod_ab          # Product    => *
#         - quot_ab          # Qutient    => /

# %%
# print the value assined to the variable "a"
print(a) 
print ("The type of the value ",a," is :", type(a))
# Out:
# 77
# The type of the value  77  is : <class 'int'>

# %%
# print the value assined to the variable "b"
print(b) 
print ("The type of the value ",b," is :", type(b))
# Out:
# 3
# The type of the value  3  is : <class 'int'>

# %%
sum_ab = a + b
print(sum_ab)
diff_ab = a - b
print(diff_ab)
prod_ab = a * b
print(prod_ab)
quot_ab = a / b
print(quot_ab)
# Out:
# 80
# 74
# 231
# 25.666666666666668

# %%
#check the type of the value quot_ab : 
print(type(quot_ab))
# Out:
# <class 'float'>

# %% [markdown]
# ### Variable Naming Convention

# %%
# age of a person 
a = 30 
a
# Out:
# 30

# %%
# age of a person (better name)
age = 30 
age
# Out:
# 30

# %%
# Use underscore for multi-word var name 
my_age = 30 
my_age
# Out:
# 30

# %%
# Don't use as a variable name
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# ---

# %% [markdown]
# ## Section 2: Data Types

# %%
type(2)
# Out:
# int

# %%
type(2.3)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
type("Bioinformatics")
# Out:
# str

# %% [markdown]
# ### Class and Object

# %%
isinstance(2, int)
# Out:
# True

# %%
isinstance(2, float)
# Out:
# False

# %%
isinstance(2.0, float)
# Out:
# True

# %%
isinstance(2, str)
# Out:
# False

# %%
isinstance('Bioinformatics', str)
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# ## Section 3: Data Type Conversion

# %%
# flot to integer 
a = 2.0 
int(a)
# Out:
# 2

# %%
# integer to float 
b = 2 
float(b)
# Out:
# 2.0

# %%
# string to int 
c = "5"
int(c)
# Out:
# 5

# %% [markdown]
# ---

# %% [markdown]
# ## Section 4: Imports

# %%
# 'generic import'
import Bio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 2
#       1 # 'generic import'
# ----> 2 import Bio
#
# ModuleNotFoundError: No module named 'Bio'

# %%
# define nickname 
import Bio as bp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 2
#       1 # define nickname
# ----> 2 import Bio as bp
#
# ModuleNotFoundError: No module named 'Bio'

# %%
# import a function from a package 
from Bio import Seq
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 2
#       1 # import a function from a package
# ----> 2 from Bio import Seq
#
# ModuleNotFoundError: No module named 'Bio'

# %% [markdown]
# ---

# %% [markdown]
# ## Section 5: Comparisons and Boolean Operations

# %%
x = 5 
y = 3

# %%
# eauqality 
x == y
# Out:
# False

# %%
# not equality 
x != y
# Out:
# True

# %%
# greater 
x > y
# Out:
# True

# %%
# less 
x < y
# Out:
# False

# %%
# greater or equal (x > y OR x == y) 
x >= y
# Out:
# True

# %%
# less or equal (x < y OR x == y)
x <= y
# Out:
# False

# %%
# AND Operation (two conditions = true; output = true) 
2 == 2 and 3 > 1
# Out:
# True

# %%
2 == 2 and 3 < 1
# Out:
# False

# %%
2 > 1 or 3 < 1
# Out:
# True

# %%
2 < 1 or 3 < 1
# Out:
# False

# %% [markdown]
# ### Arithmatic Operations

# %%
a = 10
b = 2

# %%
a + b
# Out:
# 12

# %%
a - b
# Out:
# 8

# %%
a * b
# Out:
# 20

# %%
a / b
# Out:
# 5.0

# %%
# remainder (modules operator)
a % b
# Out:
# 0

# %%
# even 
10 % 2
# Out:
# 0

# %%
# odd 
11 % 2
# Out:
# 1

# %% [markdown]
# ## Section 6: Conditional Statement

# %% [markdown]
# if condition:
#     # do something

# %%
# if statement (one condition)
num = 10 
if num > 0:
     print("positive")
# Out:
# positive

# %%
# if-else statement (two condition)
num = -10 
if num > 0:
     print("positive")
else:
    print("negative")
# Out:
# negative

# %%
# if..elif..else statement (more than two conditions)
num = 0
if num > 0:
     print("positive")
elif num == 0: 
    print("zero")
else:
    print("negative")
# Out:
# zero

# %%
num = int(input("Enter your number..."))
if num > 0:
     print("positive")
else:
    print("negative")
# Out:
# Enter your number... 0
# negative

# %% [markdown]
# ### Iteration

# %%
# print "Bangladesh" 5 times 
print("Bangladesh")
print("Bangladesh")
print("Bangladesh")
print("Bangladesh")
print("Bangladesh")
print("Bangladesh")
print("Bangladesh")
print("Bangladesh")
print("Bangladesh")
print("Bangladesh")
# Out:
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh

# %%
for i in range(10): 
    print("Bangladesh")
# Out:
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh

# %% [markdown]
# ## Section 7: String Manipulation
# Strings are sequences of characters enclosed in either single (') or double (") quotes in Python. String manipulation refers to the various operations you can perform on strings, such as concatenation, slicing, modification, and more. Python provides a variety of built-in methods that allow you to work with strings efficiently.

# %%
str1 = "Hello"
str2 = "Learner"

print(type(str1))
print(type(str2))
# Out:
# <class 'str'>
# <class 'str'>

# %% [markdown]
# #### Concatination

# %%
without_space = str1+str2
print(without_space)
# Out:
# HelloLearner

# %% [markdown]
# Add a space between the 2 strings

# %%
with_space = str1+" "+str2
print(with_space)
# Out:
# Hello Learner

# %% [markdown]
# #### Length
# Getting the number of characters in a string using len()

# %%
print("Length of Hello = ",len(str1))
print("Length of Learner = ",len(str2))
print("Length of 'Hello Learner' = ",len(with_space))
# Out:
# Length of Hello =  5
# Length of Learner =  7
# Length of 'Hello Learner' =  13

# %% [markdown]
# #### Upper & Lowercase

# %%
print(str1.lower())  # Expected output: hello
print(str2.upper())  # Expected output: LEARNER
# Out:
# hello
# LEARNER

# %% [markdown]
# #### Check for substring

# %%
text = "consistency if a picotal key in Learning "
# Check if lazy exist in text ?? 
print("Lazy" in text)  
# Check if Cons exist in text ?? 
print("Cons" in text)  
# Check if consistency exist in text ?? 
print("consistency" in text)
# Out:
# False
# False
# True

# %% [markdown]
# #### Replace Substring

# %%
text = "I love coding with R ."
new_text = text.replace("R", "Python")
print(new_text)
# Out:
# I love coding with Python .

# %% [markdown]
# #### Remove Whitspaces

# %%
sentence = "   Python is awesome !"
print(sentence)
clean_sentence = sentence.strip()
print(clean_sentence)
# Out:
#    Python is awesome !
# Python is awesome !

# %% [markdown]
# #### Split String
# Given the string "apple,banana,cherry", split it into a list of fruits.

# %%
fruits = "apple,banana,cherry"
print(fruits)
# Out:
# apple,banana,cherry

# %%
splitted_fruits = fruits.split(",")
print(splitted_fruits)  # Expected output: ['apple', 'banana', 'cherry']
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# #### Join Strings

# %%
words = ['I', 'Love', 'snakes']
sentence = " ".join(words)
print(sentence)
# Out:
# I Love snakes

# %% [markdown]
# #### Count Occurrences

# %%
seq = "ATCGGGCATACG"
count = seq.count("G")
print(count)
# Out:
# 4

# %% [markdown]
# #### String Slicing
# Slicing allows you to extract a portion of a string by specifying the start and end indices. You can also specify a step, which allows you to skip characters.
# ```
# string[start:end:step]
# ```

# %% [markdown]
# - **Basic Slicing**

# %%
text = "Python Programming"

# Slicing from index 0 to 5 (exclusive)
result = text[0:5]
print(result)   # This slices the string from index 0 to 4 (because the end index is exclusive).
# Out:
# Pytho

# %% [markdown]
# This slices the string from index 0 to 4 (because the end index is exclusive).

# %% [markdown]
# - **Slicing with Step**

# %%
text = "Python Programming"

# Slicing from index 0 to 12 with a step of 2
result = text[0:12:2]
print(result)  # Output: Pto rg
# Out:
# Pto rg

# %% [markdown]
# This extracts every second character starting from index 0 up to index 11. The characters selected are "P", "t", "o", " ", "r", "g".

# %% [markdown]
# #### Omitting Start and End
# You can omit the start and end values to slice from the beginning or to the end of the string:

# %%
text = "Python Programming"

# Slicing from the start to index 6 (exclusive)
result1 = text[:6]
print(result1)  # Output: Python
# Out:
# Python

# %%
# Slicing from index 7 to the end of the string
result2 = text[7:]
print(result2)  # Output: Programming
# Out:
# Programming

# %% [markdown]
# **Explanation:**
#
# [:6] slices from the beginning of the string up to (but not including) index 6.
#
# [7:] slices from index 7 to the end of the string.

# %% [markdown]
# #### Negative Indices
# In Python, negative indices can be used to slice the string from the end.

# %%
text = "Python Programming"

# Slicing from the second last character to the end
result = text[-2:]
print(result)  # Output: ng
# Out:
# ng

# %% [markdown]
# **Explanation:** Negative indices count from the end of the string. Here -2 starts from the second last character and slices to the end of the string.

# %% [markdown]
# #### Reverse Slicing
# You can also use negative steps to slice a string in reverse order.

# %%
text = "Python Programming"

# Slicing in reverse order
result = text[::-1]
print(result)  # Output: gnimmargorP nohtyP
# Out:
# gnimmargorP nohtyP

# %% [markdown]
# **Explanation:** [::-1] reverses the string by stepping backwards through every character.

# %% [markdown]
# ---

# %% [markdown]
# **ENJOY !!**
